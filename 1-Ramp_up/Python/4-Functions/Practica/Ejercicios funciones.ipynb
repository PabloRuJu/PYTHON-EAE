# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Functions Exercises
# ## Exercise 1
# Write a function that converts numbers from 1 to 7 into names of the days of the week. The function will consist of a single numeric argument and a string type output

# %%
def weekday(day_number):
    if day_number == 1:
        return "Monday"
    elif day_number == 2:
        return "Tuesday"
    elif day_number == 3:
        return"Wednesday"
    #continue until 7, end with else

# %% [markdown]
# ## Exercise 2
# In exercise 8 of loops, we created an inverted pyramid, whose number of floors was determined by user input. Create a function that replicates the behavior of the pyramid, and uses a single input parameter of the function to determine the number of rows of the pyramid, that is, removes the input statement.

# %%
def pyramid(rows):

    while filas > 0:
        for i in range(rows, 0, -1):
            print(i, end=" ")
        print()
        rows = rows - 1
    return "Pyramid Completed"
pyramid(7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       7         rows = rows - 1
#       8     return "Pyramid Completed"
# ----> 9 pyramid(7)
#
# Cell In[3], line 3, in pyramid(rows)
#       1 def pyramid(rows):
# ----> 3     while filas > 0:
#       4         for i in range(rows, 0, -1):
#       5             print(i, end=" ")
#
# NameError: name 'filas' is not defined

# %% [markdown]
# ## Exercise 3
# Write a function that compares two numbers. The function has two arguments and there are three possible outputs: they are equal, the first is greater than the second, or the second is greater than the first

# %%
def compare(num1, num2):
    num1 = float(num1)
    num2 = float(num2)
    if num1 == num2:
        return "The Numbers are Equal"
    elif num1 > num2:
        return str(num1) + "Is greater than" + str(num2)
    else:
        return str(num2) + "Is greater than" + str(num1)
    
compare(5, 10)
# Out:
# '10.0Is greater than5.0'

# %% [markdown]
# ## Exercise 4
# Write a function that is a letter counter. In the first argument you have to introduce a text, and the second that is the letter to count. The function must return an integer with the number of times that letter appears, both uppercase and lowercase

# %%
def counter_letters(text, letter):
    text = text.lower()
    return text.count(letter.lower())

counter_letters("This class is Awesome", "A")
# Out:
# 2

# %% [markdown]
# ## Exercise 5
# Write a function that has a single argument, a string. The output of the function must be a dictionary with the count of all the letters of that string.

# %%
def letter_count_dict(text):
    all_letters = {}

    for i in text.lower():
        if i == ' ':
            continue
        if i in all_letters:
            all_letters[i] = all_letters[i] + 1
        else:
            all_letters[i] = 1
    return all_letters

# %%
def letter_count_dict2(text):
    all_letters = {}
    text = text.lower()

    for i in text:
        if i not in all_letters:
            all_letters[i] = text.count(i)
        else:
            continue
    return all_letters

# %%
letter_count_dict2("What the hell is going on here, Oh my god")
# Out:
# {'w': 1,
#  'h': 5,
#  'a': 1,
#  't': 2,
#  ' ': 9,
#  'e': 4,
#  'l': 2,
#  'i': 2,
#  's': 1,
#  'g': 3,
#  'o': 4,
#  'n': 2,
#  'r': 1,
#  ',': 1,
#  'm': 1,
#  'y': 1,
#  'd': 1}

# %% [markdown]
# ## Exercise 6
# Write a function that adds or removes elements in a list. The function needs the following arguments:
# * list: the list where elements will be added or removed
# * command: "add" or "remove"
# * element: By default it is None.

# %%
def exercise6(list_numbers, command, element = None): #element None by default
    list_numbers = list(list_numbers)

    if command == "Add" and element != None:
        list_numbers.append(element)
        return list_numbers
    
    elif command == "Add" and element == None:
        print("You didn't provide any element")
        return list_numbers

    elif command == "Remove" and element != None:
        try:
            list_numbers.remove(element)
        except:
            print("The element", element, "is not in the list")
        return list_numbers
    
    elif command == "Remove" and element == None:
        print("You didn't provide an element to remove")
        return list_numbers

    else:
        print("Invalid command")

exercise6([1, 2, 3, 4], "Add", 6)
# Out:
# [1, 2, 3, 4, 3]

# %% [markdown]
# ## Exercise 7
# Create a function that receives an arbitrary number of words, and returns a complete sentence, separating the words with spaces.

# %%
def joined_words(*words):
    words = str(words) #Words when become string are separated letter by letter

    return " ".join(words) #Return a space while joining words

joined_words("Hello", "World", 8, "This", "Is", "A", "Test")
# Out:
# "( ' H e l l o ' ,   ' W o r l d ' ,   8 ,   ' T h i s ' ,   ' I s ' ,   ' A ' ,   ' T e s t ' )"

# %% [markdown]
# ## Exercise 8
# Write a program that obtains the nth number of the [Fibonacci sequence](https://en.wikipedia.org/wiki/Fibonacci_number). You must create a recursive function with a single argument.
#
# ```Python
# fibonacci(2) = 1
# fibonacci(4) = 3
# fibonacci(5) = 5
# fibonacci(8) = 21
# ```

# %%
def fibonacci(n):
    if n == 1:  #CONDITIONS NEEDED TO MEET FIBONACCI
        return 1
    elif n == 0:
        return 0
    else return('fibonacci(n-1)' + 'fibonacci(n-2)') #FIBONACCI REPRESENTATION

fibonacci(2) 
fibonacci(4) 
fibonacci(5) 
fibonacci(8)
# Out:
#   Cell In[24], line 6
#     else return('fibonacci(n-1)' + 'fibonacci(n-2)') #FIBONACCI REPRESENTATION
#          ^
# SyntaxError: expected ':'

# %% [markdown]
# ## Exercise 9
# Define in a single cell the following functions:
# * Function that calculates the area of a square
# * Function that calculates the area of a triangle
# * Function that calculates the area of a circle
#
# In another cell, calculate the area of:
# * Two circles with radius 10 + a triangle with base 3 and height 7
# * A square with side = 10 + 3 circles (one with radius = 4 and the other two with radius = 6) + 5 triangles with base = 2 + height = 4

# %%
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
