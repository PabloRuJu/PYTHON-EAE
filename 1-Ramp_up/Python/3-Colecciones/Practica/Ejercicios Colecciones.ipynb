# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## Exercise 1
# Given the following list:
# > ```ejer_1 = [1,2,3,4,5]```
#
# Reverse it so it looks like the following
# > ```ejer_1 = [5,4,3,2,1]```

# %%
ejer_1 = [1,2,3,4,5]
print(ejer_1)

ejer_1.reverse() #First need to reverse
print(ejer_1)
# Out:
# [1, 2, 3, 4, 5]
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## Exercise 2
# Raise all elements of the list to the square
# > ```ejer_2 = [1,2,3,4,5]```

# %%
ejer_2 = [1,2,3,4,5]
print(ejer_2)
                                        ##len(ejer_2) Returns the number of values within the list
for power in range(len(ejer_2)):    #ASK DAVE
   ejer_2[power] = ejer_2[power]**2  #WHY DOES THIS HOLD THE LIST????
print(ejer_2)

##NO IDEA
# Out:
# [1, 2, 3, 4, 5]
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Exercise 3
# Create a new list with all combinations of the following two lists:
# > ```ejer_3_1 = ["Hello", "friend"]```
# >
# > ```ejer_3_2 = ["How", "are"]```
#
# Get the following output:
#
# ['Hello How', 'Hello are', 'friend How', 'friend are']

# %%
ejer_31 = ["Hello", "friend"]
ejer_32 = ["How", "are"]

exdumb= []

for words1 in ejer_31:
    for words2 in ejer_32:
        exdumb.append(words1+""+words2) #Blank variable and append both sets of words

print(exdumb)
# Out:
# ['HelloHow', 'Helloare', 'friendHow', 'friendare']

# %% [markdown]
# ## Exercise 4
# Given the following list, find the index of value 45 and replace it with 0
# > ```ejer_4 = [20, 47, 19, 29, 45, 67, 78, 90]```

# %%
ejer_4= [20,47,19,29,45,67,78,90]
ejer_4.index(45)

#ejer_4.remove(45) #NO NEED OF COMILLAS TO REMOVE NUMBERS
#ejer_4.insert(4, 0) #INSERT(list position, value inserted)
#print(ejer_4)
# Out:
# 4

# %%
ejer_4.remove(45) #NO NEED OF COMILLAS TO REMOVE NUMBERS
ejer_4.insert(4, 0) #INSERT(list position, value inserted)
print(ejer_4)
# Out:
# [20, 47, 19, 29, 0, 67, 78, 90]

# %% [markdown]
# ## Exercise 5
# Given the following list, delete all values equal to 3
# > ```ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]```
#
# TIP: Do not try to delete elements from the list you are iterating. Make a copy with `ejer_5.copy()`.

# %%
ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]
print(ejer_5)

ejer_5.remove(3) 
print(ejer_5)
# Out:
# [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]
# [20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]

# %%
print(ejer_5) #RUN 4 TIMES AND ELIMINATE ALL 3's
ejer_5.remove(3)
print(ejer_5)
# Out:
# [20, 47, 19, 29, 45, 67, 78, 90, 3]
# [20, 47, 19, 29, 45, 67, 78, 90]

# %%
ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3] #CORRECT ANSWER

for numbers in ejer_5.copy():   # iterate over a copy
    if numbers == 3:
        ejer_5.remove(numbers)

print(ejer_5)
# Out:
# [20, 47, 19, 29, 45, 67, 78, 90]

# %% [markdown]
# ## Exercise 6
# 1. Create a tuple with 3 elements
# 2. Create another tuple with one element and check its type
# 3. Create a tuple with elements of different types
# 4. Print to screen the first and last element of the tuple from section 3. Use `len` for the last one
# 5. Add an element to the tuple from section 3.
# 6. Delete an element from the tuple in section 5, which is roughly in the middle.
# 7. Convert the tuple from section 5 into a list

# %%
tuple = (3, 6, 9) #1
print(tuple)
tuple2=('Fanta',)#2
print(tuple2)
print(type(tuple2))

tuple3= (4, 'Hello', True) #Is this part3??

print("First element:", tuple3[0])#4
print("Last element:", tuple3[len(tuple3) - 1])

tuple4 = tuple + tuple3#5
print(tuple4)

# Remove element at index 2 (roughly middle)
tuple4 = tuple4[:2] + tuple4[3:] 
print(tuple4)
# Out:
# (3, 6, 9)
# ('Fanta',)
# <class 'tuple'>
# First element: 4
# Last element: True
# (3, 6, 9, 4, 'Hello', True)
# (3, 6, 4, 'Hello', True)

# %% [markdown]
# ## Exercise 7
# Concatenate all elements of the tuple into a single string. To do this, use the `.join()` method of Strings
# > ```ejer_7 = ("one", "hundred", "by", "band")```
#
# Result: `one hundred by band`

# %%
ejer_7 = ('one', 'hundred', 'by', 'band')

ejer_7 = " ".join(ejer_7) #Remove commas and spaces
print(ejer_7)
# Out:
# one hundred by band

# %% [markdown]
# ## Exercise 8
# Get the third element of the following tuple, and the third one starting from the end
# > ```ejer_8 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3)```

# %%
ejer_8= (3,20,3,47,19,3,29,45,67,78,90,3,3)
print(ejer_8[2])
print(ejer_8[10]) #NOT EVEN IN THE NOTES
# Out:
# 3
# 90

# %% [markdown]
# ## Exercise 9
# 1. How many times is 3 repeated in the following tuple?
# 2. Create a new tuple with elements from position 5 to 10.
# 3. How many elements does the `ejer_9` tuple have?
# > ```ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)```

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
ejer_9.count(3)

newtuple = ejer_9[4:10] #[Starting after...:Stopping at] IMPORTANT
print(newtuple)
print(len(ejer_9)) #Count elements in a tuple
# Out:
# (19, 3, 29, 45, 67, 78)
# 26

# %% [markdown]
# ## Exercise 10
# Check if the number 60 is in the tuple from exercise 9

# %%
if 60 in ejer_9:
    print("60 is in the tuple")
else:
    print("60 is NOT in the tuple")
# Out:
# 60 is NOT in the tuple

# %% [markdown]
# ## Exercise 11
# 1. Convert the tuple from section 10 into a list
# 2. Convert the tuple from section 10 into a set
# 3. Convert the tuple from section 10 into a dictionary. Also use the indices

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
createdlist = list(ejer_9) #Tuple to list
print(createdlist)
print(type(createdlist))

print(set(ejer_9)) #Tuple to set
#print(set_from_tuple)
#print(type(set_from_tuple))
# Out:
# [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7]
# <class 'list'>
# {2, 3, 67, 5, 4, 7, 6, 9, 45, 78, 47, 19, 20, 90, 29}

# %%
dictionary_tuple = {}

for i in range(len(ejer_9)): #PRACTICE #Identifying all values from ejer_9 as 'i'
    dictionary_tuple[i] = ejer_9[i]

print(dictionary_tuple)
# Out:
# {0: 3, 1: 20, 2: 3, 3: 47, 4: 19, 5: 3, 6: 29, 7: 45, 8: 67, 9: 78, 10: 90, 11: 3, 12: 3, 13: 5, 14: 2, 15: 4, 16: 7, 17: 9, 18: 4, 19: 2, 20: 4, 21: 3, 22: 3, 23: 4, 24: 6, 25: 7}

# %% [markdown]
# ## Exercise 12
# Convert the following list into a dictionary
# > ```ejer_12 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]```
#
# TIP: You can use two control variables in a `for` loop. One for each value of the tuples.

# %%
ejer_12 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]

dict1 = dict(ejer_12) ##Not clear 
print(dict1)
# Out:
# {'x': 3, 'y': 2, 'z': 1}

# %%
result = {}

for key, value in ejer_12:
    if key not in result: ##CORRECT? WTF
        result[key] = []
    result[key].append(value)

print(result)
# Out:
# {'x': [1, 2, 3], 'y': [1, 2], 'z': [1]}

# %%
##ASK DAVE

# %% [markdown]
# ## Exercise 13
# 1. Create an ascending sorted list with the dictionary keys
# 2. Create another list sorted in descending order with the values
# 3. Add a new key/value
# 4. Find the key with value 2 in the dictionary
# 5. Iterate the key and value of the dictionary with a single for loop
# > ```ejer_13 = {4:78, 2:98, 8:234, 5:29}```

# %%
ejer_13 = {4: 78, 2: 98, 8: 234, 5: 29}
sorted_keys = sorted(ejer_13.keys())#1 SORTING KEYS
print(sorted_keys)

sorted_values_descending = sorted(ejer_13.values(), reverse=True) #Sorting then reversing
print(sorted_values_descending)

ejer_13[10] = 50 #Adding new value to Dictionary
print(ejer_13)

for key, value in ejer_13.items():
    if value == 2:#FINDING KEY NUMBER 2
        print("Key with value 2:", key)
    else:
        print(False)

for key, value in ejer_13.items(): #5???
    print("Key:", key, "Value:", value)
# Out:
# [2, 4, 5, 8]
# [234, 98, 78, 29]
# {4: 78, 2: 98, 8: 234, 5: 29, 10: 50}
# False
# False
# False
# False
# False
# Key: 4 Value: 78
# Key: 2 Value: 98
# Key: 8 Value: 234
# Key: 5 Value: 29
# Key: 10 Value: 50

# %% [markdown]
# ## Exercise 14
# Merge both dictionaries. To do this, use `update`
# > ```ejer_14_1 = {1: 11, 2: 22}```
# >
# > ```ejer_14_2 = {3: 33, 4: 44}```

# %%
ejer_14_1 = {1: 11, 2: 22}
ejer_14_2 = {3: 33, 4: 44}

ejer_14_1.update(ejer_14_2) #UPDATE to merge two dictionaries
print(ejer_14_1)
# Out:
# {1: 11, 2: 22, 3: 33, 4: 44}

# %% [markdown]
# ## Exercise 15
# Sum all values of the dictionary
# > ```ejer_15 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_15 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}
print(sum(ejer_15.values())) #SUMMING all values on a dictionary
# Out:
# 165

# %% [markdown]
# ## Exercise 16
# Multiply all values of the dictionary
# > ```ejer_16 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_16 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55} 
result = 1                                      #WHAT IS THIS?? NO IDEA

for value in ejer_16.values():
    result *= value ##NEED EXPLANATION

print(result)
# Out:
# 1

# %% [markdown]
# ## Exercise 17
# 1. Create a set with three elements
# 2. Add a fourth
# 3. Delete the last element added
# 4. Delete element 10, if it is present. Use `discard()`

# %%
finalset = {6, 9, 4}
print(finalset)

finalset.add('hello')
print(finalset)

finalset.discard('hello') #DIFFERENCE WITH REMOVE???
print(finalset)

finalset.discard(10)
print(finalset)
# Out:
# {9, 4, 6}
# {9, 4, 'hello', 6}
# {9, 4, 6}
# {9, 4, 6}
